# %%
import pandas as pd

# %%
data = pd.read_csv('akarpov_37659/hm_1_heart_disease_classification/heart_disease_data/HeartDiseaseData.csv')

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>ID</th>
#       <th>Age</th>
#       <th>Sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>num</th>
#       <th>Place</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>28</td>
#       <td>male</td>
#       <td>atypical angina</td>
#       <td>130.0</td>
#       <td>132.0</td>
#       <td>False</td>
# ...
